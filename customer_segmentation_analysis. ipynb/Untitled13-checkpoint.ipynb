# %%
import pandas as pd

# %%
df = pd.read_excel("Customer_Segmentation_dataset.xlsx")

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6

# %%
df.shape
# Out:
# (120, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               120 non-null    int64
#  1   Gender           120 non-null    object
#  2   Ever_Married     120 non-null    object
#  3   Age              120 non-null    int64
#  4   Graduated        120 non-null    object
#  5   Profession       119 non-null    object
#  6   Work_Experience  103 non-null    float64
#  7   Spending_Score   120 non-null    object
#  8   Family_Size      114 non-null    float64
#  9   Var_1            118 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# ID                  0
# Gender              0
# Ever_Married        0
# Age                 0
# Graduated           0
# Profession          1
# Work_Experience    17
# Spending_Score      0
# Family_Size         6
# Var_1               2
# dtype: int64

# %%
df.dtypes
# Out:
# ID                   int64
# Gender              object
# Ever_Married        object
# Age                  int32
# Graduated           object
# Profession          object
# Work_Experience    float64
# Spending_Score      object
# Family_Size        float64
# Var_1               object
# dtype: object

# %%
df.describe()
# Out:
#                   ID         Age  Work_Experience  Family_Size
# count     112.000000  112.000000       112.000000   112.000000
# mean   459172.258929   49.750000         1.912968     2.714286
# std       110.443393   19.926215         2.713258     1.442149
# min    458989.000000   18.000000         0.000000     1.000000
# 25%    459078.500000   34.500000         0.000000     2.000000
# 50%    459170.500000   48.000000         1.000000     2.000000
# 75%    459263.250000   67.250000         2.019417     4.000000
# max    459363.000000   89.000000        11.000000     8.000000

# %%
df['Gender'].value_counts()
df['Spending_Score'].value_counts()
df['Profession'].value_counts()
# Out:
# Profession
# Artist           42
# Healthcare       18
# Lawyer           16
# Executive         9
# Doctor            9
# Entertainment     8
# Engineer          5
# Marketing         2
# Homemaker         2
# Unknown           1
# Name: count, dtype: int64

# %%
df.groupby('Gender')['Spending_Score'].value_counts()
# Out:
# Gender  Spending_Score
# Female  Low               23
#         High              14
#         Average           12
# Male    Low               35
#         Average           14
#         High              14
# Name: count, dtype: int64

# %%
df.groupby('Profession')['Age'].mean()
# Out:
# Profession
# Artist           52.928571
# Doctor           49.555556
# Engineer         36.800000
# Entertainment    39.625000
# Executive        53.222222
# Healthcare       26.444444
# Homemaker        71.500000
# Lawyer           73.375000
# Marketing        30.500000
# Unknown          69.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt

df['Gender'].value_counts().plot(kind='bar')
plt.show()

# %%
df.info()
df.isnull().sum()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               112 non-null    int64
#  1   Gender           112 non-null    object
#  2   Ever_Married     112 non-null    object
#  3   Age              112 non-null    int32
#  4   Graduated        112 non-null    object
#  5   Profession       112 non-null    object
#  6   Work_Experience  112 non-null    float64
#  7   Spending_Score   112 non-null    object
#  8   Family_Size      112 non-null    float64
#  9   Var_1            112 non-null    object
# dtypes: float64(2), int32(1), int64(1), object(6)
# memory usage: 9.2+ KB
#                   ID         Age  Work_Experience  Family_Size
# count     112.000000  112.000000       112.000000   112.000000
# mean   459172.258929   49.750000         1.912968     2.714286
# ...

# %%
df.groupby('Profession')['Spending_Score'].value_counts(normalize=True)
# Out:
# Profession     Spending_Score
# Artist         Average           0.404762
#                Low               0.380952
#                High              0.214286
# Doctor         Average           0.444444
#                Low               0.444444
#                High              0.111111
# Engineer       Low               1.000000
# Entertainment  Low               1.000000
# Executive      High              0.666667
#                Low               0.222222
#                Average           0.111111
# Healthcare     Low               0.833333
#                High              0.111111
#                Average           0.055556
# Homemaker      High              0.500000
#                Low               0.500000
# Lawyer         High              0.562500
#                Low               0.250000
#                Average           0.187500
# Marketing      Low               1.000000
# Unknown        Low               1.000000
# Name: proportion, dtype: float64

# %%
df.groupby('Ever_Married')['Spending_Score'].value_counts(normalize=True)
# Out:
# Ever_Married  Spending_Score
# No            Low               1.000000
# Yes           High              0.378378
#               Average           0.351351
#               Low               0.270270
# Name: proportion, dtype: float64
